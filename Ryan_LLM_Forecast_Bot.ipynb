# %% [markdown]
# <a href="https://colab.research.google.com/github/ryooan/metaculus-bot-forecaster/blob/main/Ryan_LLM_Forecast_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LLM Forecasting Bot
# *Created by Kirill and Tom, revised by Ryan*
#
# The code below is used for making LLM-powered forecasts in Metaculus' [AI benchmarking competition](https://www.metaculus.com/project/ai-benchmarking-pilot/).
#
# Specifically, it does the following:
#
# * Gets questions from the project page using the Metaculus API
# * Gets four separate forecasts from the LLM, three independently and the fourth assessing the reasoning of the first three and producing its own.
# * Predicts on the Metaculus questions and shares a comment describing the reasoning of the fourth LLM forecast.
#
# Features and options:
#
# * Allows you to choose whether it repredicts on questions it's already forecasted on or ignores them.
# * Allows for the use of [Perplexity search](https://www.perplexity.ai/) for additional research, using a prompt formed by an LLM.
#     * *Previously this allowed for the use of pre-computed Perpelxity results, but this is no longer supported by Metaculus.*
# * Can be used with an automated workflow via Github actions to monitor the project for new open questions and make forecasts when there are some
#     * See [this Github repo](https://github.com/ryooan/metaculus-bot-forecaster) for how to set this up

# %% [markdown]
# ### 🚨🚨🚨 Warning 🚨🚨🚨
#
# **You are responsible for monitoring the costs of your implementation, especially if using the automated Github workflow. Cost estimates computed by this notebook are rough estimates only, make sure to check and monitor how much you are spending and the funds in your relevant accounts.**

# %% [markdown]
# ## Getting Started
#
# ### Make a Metaculus Bot Account
# The first step will be to make a Metaculus bot account. Instructions for how to do this have likely already been provided to you, either via a page on Metaculus or at an event.
#
# ### Secrets and Tokens
#
# You need to set secrets 1) and 2) in order to make forecasts. Secrets 3) and 4) are necessary if you will be using Perplexity research.
#
# 1) METACULUS_TOKEN (you can find it or create it here - https://www.metaculus.com/admin/authtoken/tokenproxy/, or ask Metaculus to share it with you).
#
# 2) OPENAPI_API_KEY - (you can find it here https://platform.openai.com/settings/profile?tab=api-keys).
#
# 3) PERPLEXITY_API_KEY - You can generate an API key here: https://docs.perplexity.ai/docs/getting-started
#
# These secrets can be set in your Google colab account using the key on the left side.
#
# *See the [Github repo](https://github.com/ryooan/metaculus-bot-forecaster) for special instructions necessary for setting your secrets in Github if you intend to use the automated Github action.*
#
# *Note: previously this also used a QUESTIONS_API_KEY which got some precomputed Perplexity results stored by Metaculus, but this is no longer supported by Metaculus.*
#
# ### Setting Inputs
#
# Once your tokens are set correctly, you can proceed to the [Inputs section](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?authuser=2#scrollTo=6cbruBaVtaZh). That should be the only section most users will need. More advanced users can edit the [Setup](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?authuser=2#scrollTo=tNl_mbJaX60R) and [Code](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?authuser=2#scrollTo=k8vtze4SXtR3) sections if desired, but this is not recommended unless you have coding experience.

# %% [markdown]
# ## Setup
#
# It is recommended that you do not edit these cells unless you have coding experience.
#
#
#
# ---

# %%
from IPython.display import HTML, display

def set_css(*args, **kwargs):
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

#according to this link the above wraps the output text: https://stackoverflow.com/questions/58890109/line-wrapping-in-collaboratory-google-results
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# !pip install openai
# !pip install tiktoken
import datetime
import json
import os
import requests
import tiktoken
import re

from openai import OpenAI

#use the below to detect if it's being run in google colab, if it's not this skips an error
def in_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_colab():
    from google.colab import userdata
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.35.12)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.6.2)

# %%
#the below is used to get secrets when using github actions to automate
#initialize
token = None
questions_api_key = None
perplexity_api_key = None

# Function to load secrets from the specified path
def load_secrets(secrets_path):
    try:
        with open(secrets_path, 'r') as secrets_file:
            secrets = json.loads(secrets_file.read())
            for k, v in secrets.items():
                os.environ[k] = v
    except Exception as e:
        print(f"Error loading secrets from {secrets_path}: {e}")

# Main code block
try:
    if 'secretsPath' in globals():
        print(f"secretsPath exists: {secretsPath}")
        load_secrets(secretsPath)

        token = os.environ['METACULUS_TOKEN']
        questions_api_key = os.environ['QUESTIONS_API_KEY']
        perplexity_api_key = os.environ['PERPLEXITY_API_KEY']
    else:
        raise NameError("secretsPath not defined")
except NameError:
    print("Loading secrets from userdata (Google Colab)")
    token = userdata.get('METACULUS_TOKEN')
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
    questions_api_key = userdata.get('QUESTIONS_API_KEY')
    perplexity_api_key = userdata.get('PERPLEXITY_API_KEY')
except KeyError as e:
    print(f"Missing required environment variable: {e}")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Loading secrets from userdata (Google Colab)

# %% [markdown]
# ## Inputs
#
# The cell below contains all of the main settings that you can change. See comments in the cell for an explanation of each. Modify them as you see fit and then run all of the cells below to forecast.
#
# *You can press Ctrl+F10 to run all of the cells after the selected one.*

# %%
PROJECT_ID = 3349  # 3129 is ID of AI Becnhmarking Pilot project. We kindly ask you not to forecast on any public tournaments or public questions in general
MAX_QUESTIONS_TO_FORECAST = 1_000  # You can set it to some small number for testing or to 1_000_000 to forecast on all available questions
REPREDICT = False # if this is false it won't predict on questions it has previously already predicted on. Set it to true to repredict on all open questions, even if it has made previous predictions.
SUBMIT_FORECASTS = True # If set to False - forecast, but don't submit results to Metaculus platform. If set to True - forecast, and submit results to Metaculus platform
USE_PERPLEXITY_RECENT = True # If set to true the perplexity search used is one that looks for the most recent news on the subject using a GPT prompt completion informed by the forecasting question.
QUESTION_IDS_TO_FORECAST = None # Set to None to disable custom filtering by ID. Set to a list of IDs to only forecast on selected questions, i.e. [24191, 24190, 24189]

# The forecaster weights are used to produce a weighted average of the forecasts. You can adjust these weights to favor a certain forecaster/prompt more heavily.
# Weights should sum to 1.
forecaster1_weight = 0.2
forecaster2_weight = 0.2
forecaster3_weight = 0.2
forecaster4_weight = 0.4

# Prompts
# The prompts used are below, these can be edited to hone your LLM forecasts.
# Here is a glossary of the variables that can be inserted and used in the prompts.
# [[title]]: This is the question text, what shows up at the top of the Metaculus question page
# [[resolution_criteria]]: This is the resolution criteria section of the question, excluding fine print
# [[fine_print]]: This is the fine print section of the question.
# [[background]]: This is the background section of the resolution criteria.
# [[today]]: The current date
# [[forecaster1]] through {forecaster3}: These are the LLM outputs of forecasters 1 through 3, currently being used to feed into the input of forecaster 4 for it to assess in its own forecast.
# [[summary_report]]: This is research from Perplexity. If USE_PERPLEXITY_RECENT is True, this will be the Perplexity info returned when the output of LLM_question_completion is passed to Perplexity.
                  # If USE_PERPLEXITY_RECENT is False and ENABLE_PERPLEXITY_RESEARCH is True, it will return pre-computed Perplexity research on the question stored by Metaculus.
                  # If both are false it will not return anything.

# The LLM_question_completion prompt is used to ask the LLM what question it should ask Perplexity, if using USE_PERPLEXITY_RECENT
LLM_question_completion = """
You're being asked the following forecasting question:

The question is:
[[title]]

And it has these specific resolution details:
[[resolution_criteria]]

Fine print:
[[fine_print]]

To get the latest news that will help you forecast on the question, you need to ask your web search tool one question that would be most valuable to help you forecast
on this question. The question should be posed so that the web search tool will provide you with the most recent information, including the latest information on the progress toward
the criteria in the forecasting question being met. Please complete the sentence below with the most valuable question to ask:

"What is the most recent news available and prior occurrences related to. . . "
"""

# Prompt 1 is used by forecaster 1, with PROMPT_TEMPLATE appended to the end
prompt1 = """
You are a professional forecaster interviewing for a job. The interviewer is also a professional forecaster, with a strong track record of accurate forecasts of the future.
They will ask you a question, and your task is to provide the most accurate forecast you can. To do this, you evaluate past data and trends carefully, make use of comparison classes
of similar events, take into account base rates about how past events unfolded, and outline the best reasons for and against any particular outcome.
You know that great forecasters don't just forecast according to the "vibe" of the question and the considerations.
Instead, they think about the question in a structured way, recording their reasoning as they go,
and they always consider multiple perspectives that usually give different conclusions, which they reason about together.
You can't know the future, and the interviewer knows that, so you do not need to hedge your uncertainty, you are simply trying to give
the most accurate numbers that will be evaluated when the events later unfold.

"""

# Prompt 2 is used by forecaster 2, with PROMPT_TEMPLATE appended to the end
prompt2 = """
You are a professional forecaster being tested on your skill. You are being asked a question for which you must provide the most accurate forecast you can.
Reason step by step about the best forecast, carefully considering the information you are presented with and the potential that some of the
background information and information provided by your research assistant may be out of date or conflicting.
You also know that a key forecasting practice is to consider the outside view, thinking carefully about reference classes and base rates and how often similar events
have happened in the past.

"""

# Prompt 3 is used by forecaster 3, with PROMPT_TEMPLATE appended to the end
prompt3 = """
You are a professional forecaster trying your best to produce an accurate forecast for the question below. You have a keen eye for detail, and know that
the resolution criteria and fine print of a question often contain important edge cases that should be considered. You also know that rookie forecasters
tend to be underconfident, and so your forecasts should be confident and extremize some of the way toward 1% or 99%. You're also aware that forecasting questions tend
to be biased, so when forecasting questions asks about things that would be a departure from the norm or from business as usual, those things tend not to happen.
You will use that knowledge to make the best forecast you can, and describe your reasoning step by step.

"""

# Forecaster 4 uses prompt 4 parts 1 and 2, with PROMPT_TEMPLATE inserted between part 1 and part 2
prompt4part1 = """
You are a professional forecaster trying your best to produce an accurate forecast for the question below.

"""

prompt4part2 = """
Now that you know what the question asks and some relevant background and research, your job is to make the best forecast you can. You know that examining the reasoning of other
forecasters is an excellent way to improve your own forecast. Below I have provided the reasoning from three other forecasters who predicted on the same question.
Examine their reasoning and use it to inform your own, using your expertise as a forecaster to assess which reasoning seems strongest and which seems flawed,
as well as which reasoning seems to incorporate the most accurate information about base rates and historic reference classes. Construct your own reasoning and forecast,
describing your reasoning step by step and incorporating the strongest arguments from the other forecasters in a way that improves your own reasoning. First produce a
one sentence summary of the reasoning of each forecaster (repeating the final probability each predicted), then describe your forecast.

Forecaster A:
[[forecaster1]]

Forecaster B:
[[forecaster2]]

Forecaster C:
[[forecaster3]]
"""

# PROMPT_TEMPLATE is used with the above prompts to share the details about the question with the LLM.
PROMPT_TEMPLATE = """

The question is:
[[title]]

Here are details about how the outcome of the question will be determined, make sure your forecast is consistent with these:
[[resolution_criteria]]

Here is the question's fine print that you need to be consistent with in your forecast:
[[fine_print]]

Here is some background of the question, though note that some of the details may be out of date:
[[background]]

Your research assistant provides the following information that is likely more up to date:
[[summary_report]]

Today is [[today]].

Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
"""
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ## Code
#
# It is recommended that you do not edit the below unless you have coding experience.
#
# Note that currently the LLM is set to gpt-4o, and this is specified in the code below. This can be changed by advanced users, though changing between OpenAI models is much simpler than changing to a model from a different AI organizations.
#
# ---

# %% [markdown]
# Getting questions (only binaries)
#
# Getting them 10 at a time, you can change offset to "scroll" through them

# %%
url = "https://www.metaculus.com/api2/questions/"

params = {
    "has_group": "false",
    "order_by": "-activity",
    "forecast_type": "binary",
    "project": PROJECT_ID,
    "status": "open", # can change this to 'closed' for testing where you're not submitting a forecast, otherwise leave as open
    "type": "forecast",
    "title-and-description-only": "true",
}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def yield_all_questions():
  limit = 10 # This is a page limit, not question limit
  n = 0
  new_questions_found = False

  while True:
    offset = n * limit
    response = requests.get(
        url,
        params={**params, "limit": limit, "offset": offset},
        headers={"Authorization": f"Token {token}"}
    )
    response.raise_for_status()
    questions = response.json().get("results")

    # if repredict is true it will skip to the else and predict on all the questions
    # if repredict is false it will see if "my_predictions" is empty or not for each question, and only predict on questions without a prediction
    if not REPREDICT:
        for question in questions:
            question_id = question['id']

            guess_response = requests.get(
                f"{url}{question_id}/",
                headers={"Authorization": f"Token {token}"}
            )
            guess_response.raise_for_status()

            if not guess_response.json().get("my_predictions"):
                new_questions_found = True
                yield question
    else:
        new_questions_found = True
        yield from questions

    if not response.json().get("next"):
      break
    n += 1

  if not new_questions_found:
        print("No new questions to predict on.")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def find_number_before_percent(s):
    # Use a regular expression to find all numbers followed by a '%'
    matches = re.findall(r'(\d+)%', s)
    if matches:
        # Return the last number found before a '%'
        return int(matches[-1])
    else:
        # Return None if no number found
        return None
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# this is used to replace the {} keys with [[]], since sometimes the LLM output uses {} when formatting code.

def replace_keys(text, key_dict, delimiter='[[', end_delimiter=']]'):
    pattern = re.compile(re.escape(delimiter) + '(.*?)' + re.escape(end_delimiter))
    def replace(match):
        key = match.group(1)
        return key_dict.get(key, match.group(0))  # Return the original if key not found
    return pattern.sub(replace, text)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def predict(question_id, prediction_percentage):
  url = f"https://www.metaculus.com/api2/questions/{question_id}/predict/"
  response = requests.post(
      url,
      json={
        "prediction": float(prediction_percentage) / 100
      },
      headers={"Authorization": f"Token {token}"},
  )
  response.raise_for_status()
  print(f"Successfully predicted {prediction_percentage} on question {question_id}")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def formulate_comment(prediction_json):
  comment_blocks = []
  if "reasoning_base_rate" in prediction_json:
    comment_blocks.append("## Base rate estimation")
    comment_blocks.append(prediction_json["reasoning_base_rate"])
  if "reasoning_reference_classes" in prediction_json:
    comment_blocks.append("## Reference classes")
    comment_blocks.append(prediction_json["reasoning_reference_classes"])
  if "reasoning_other" in prediction_json:
    comment_blocks.append("## Additional")
    comment_blocks.append(prediction_json["reasoning_other"])
  return "\n".join(comment_blocks) if comment_blocks else "No reasoning provided"
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def comment(question_id, comment_text):

  # for submit_type choose "S" to post regular comment and "N" for private. Tournament submissions should be private comments.
  url = f"https://www.metaculus.com/api2/comments/"
  response = requests.post(
    url,
    json={
      "comment_text":comment_text,"submit_type":"N","include_latest_prediction":True,"question":question_to_forecast['id']
    },
    headers={"Authorization": f"Token {token}"},
  )
  response.raise_for_status()
  print("Comment Success!")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def get_perplexity_research(question_id):
  url = "https://ml.metaculus.com/questions-api/perplexity-research-results/"
  headers = {
    "accept": "application/json",
    "X-API-Key": questions_api_key,
    "content-type": "application/json"
  }
  params = {
    "question_id": question_id
  }
  response = requests.get(url=url, params=params, headers=headers)
  if response.status_code == 404:
    print("No Perplexity research found")
    return "No results found, please use your own knowledge and judgement to forecast"
  content = response.text

  print("Generated research from perplexity:")
  print(content)
  return content
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def estimate_pricing(input, output, model):
  encoding = tiktoken.encoding_for_model(model)
  input_len = len(encoding.encode(input))
  output_len = len(encoding.encode(output))


  # hard coding for now, maybe make it smarter later
  # units of $ per token
  gpt4o_input_pricing = 5 / 1_000_000
  gpt4o_output_pricing = 15 / 1_000_000

  input_cost = input_len * gpt4o_input_pricing
  output_cost = output_len * gpt4o_output_pricing
  total_cost = input_cost + output_cost

  return input_cost, output_cost, total_cost
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def get_forecast(today, client, question_to_forecast, prompt, summary_report, model):

  title = question_to_forecast["title"]
  resolution_criteria = question_to_forecast["resolution_criteria"]
  background = question_to_forecast["description"]
  if question_to_forecast["fine_print"]:
    fine_print = question_to_forecast["fine_print"]
  else:
    fine_print = "none"

  print("")

  prompt_dict = {
      "title": title,
      "summary_report": summary_report,
      "today": today,
      "background": background,
      "fine_print": fine_print,
      "resolution_criteria": resolution_criteria,
  }

  prompt_content = replace_keys(prompt, prompt_dict)

  print("Here is the prompt used:")
  print(prompt_content)
  print("")

  chat_completion = client.chat.completions.create(
    model=model,
    messages=[
      {
        "role": "user",
        "content": prompt_content
      }
    ]
  )

  gpt_text = chat_completion.choices[0].message.content

  #estimate cost
  input_cost, output_cost, total_cost = estimate_pricing(prompt_content, gpt_text, model)

  # Regular expression to find the number following 'Probability: '
  probability_match = find_number_before_percent(gpt_text)

  # Extract the number if a match is found
  if probability_match:
      probability = int(probability_match) # int(match.group(1))
      print(f"The extracted probability is: {probability}%")
      #probability = min(max(probability, 3), 97) # To prevent extreme forecasts
  else:
      probability = None
      print("No probability found in the text! Skipping!")
  return probability, gpt_text, input_cost, output_cost, total_cost
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def call_perplexity(perplexity_prompt):
  model = "llama-3-sonar-large-32k-online"
  perplexity_token_pricing = 1/1_000_000
  perplexity_cost_fixed = 5/1_000

  url = "https://api.perplexity.ai/chat/completions"
  headers = {
    "accept": "application/json",
    "authorization": f"Bearer {perplexity_api_key}",
    "content-type": "application/json"
  }
  payload = {
    "model": model,
    "messages": [
      {
        "role": "system",
        "content": "Be precise and provide all the important details."
      },
      {
        "role": "user",
        "content": perplexity_prompt
      }
    ]
  }
  response = requests.post(url=url, json=payload, headers=headers)
  response.raise_for_status()
  content = response.json()["choices"][0]["message"]["content"]
  print("Generated research from perplexity:")
  print(content)

  # get token and cost estimate

  # currently using the GPT tokenizer with a 1.3 multiplier. Hacky and wrong, but rough estimate.
  # See here for 1.3 factor estimate source: https://github.com/continuedev/continue/issues/878

  multiplier = 1.3
  encoding = tiktoken.encoding_for_model('gpt-4o')
  input_text = perplexity_prompt
  output_text = content
  input_len = len(encoding.encode(input_text)) * multiplier
  output_len = len(encoding.encode(output_text)) * multiplier

  input_cost = input_len * perplexity_token_pricing
  output_cost = output_len * perplexity_token_pricing
  fixed_cost = perplexity_cost_fixed
  total_cost = input_cost + output_cost + perplexity_cost_fixed

  print(f"Total perplexity call cost: ${total_cost}")

  return content, total_cost
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def clean_gpt_turbo_markdown(text: str) -> str:
  match = re.search(r"```[\w]+\s+(.*?)\s+```", text, re.DOTALL)
  if match:
    cleaned_text = match.group(1).strip()
  else:
    cleaned_text = text
  return cleaned_text
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Forecast on all questions

# %%
today = datetime.datetime.now().strftime("%Y-%m-%d")
client = OpenAI()
model = "gpt-4o"
ENABLE_PERPLEXITY_RESEARCH = False  # Previously this could be set to True to get and use pre-computed Perplexity research results for the question, set to False otherwise.
# However, Metaculus no longer supports pre-computed Perplexity research, so it has been permanently set to False here to skip over that setp.

promptset = [prompt1 + PROMPT_TEMPLATE, prompt2 + PROMPT_TEMPLATE, prompt3 + PROMPT_TEMPLATE]

forecasted_count = 0

for question_to_forecast in yield_all_questions():
  if forecasted_count >= MAX_QUESTIONS_TO_FORECAST:
    break
  if QUESTION_IDS_TO_FORECAST is not None and question_to_forecast["id"] not in QUESTION_IDS_TO_FORECAST:
    continue

  print(question_to_forecast["id"], question_to_forecast["title"])

  #define perplexity research to use
  perplexity_total_cost = "N/A"

  if ENABLE_PERPLEXITY_RESEARCH:
    summary_report = get_perplexity_research(question_to_forecast["id"])
  else:
    summary_report = "No results found, please use your own knowledge and judgement to forecast"

  # set summary_report to the perplexity recent search if enabled
  if USE_PERPLEXITY_RECENT:
    #get prompt completion for use with perplexity
    probability, perplexity_recent_prompt, completion_input_cost, completion_output_cost, completion_total_cost = get_forecast(today, client, question_to_forecast, LLM_question_completion, summary_report, model)

    print(f"The completed question posed to perplexity reads: {perplexity_recent_prompt}")
    #get recent news from perplexity
    perplexity_content, perplexity_cost = call_perplexity(perplexity_recent_prompt)

    summary_report = perplexity_content
    perplexity_total_cost = completion_total_cost + perplexity_cost

  # need to iterate through prompts here
  all_forecasts = []
  overall_cost = 0

  for prompt in promptset:
    probability, gpt_text, input_cost, output_cost, total_cost = get_forecast(today, client, question_to_forecast, prompt, summary_report, model)
    all_forecasts.append((probability, gpt_text, input_cost, output_cost, total_cost))
    overall_cost += total_cost
    print(f"Output Reasoning:")
    print(gpt_text)
    print(f"Input cost: ${input_cost}")
    print(f"Output cost: ${output_cost}")
    print(f"Total cost: ${total_cost}")
    print(f"Perplexity search costs (including LLM prompt completion): ${completion_total_cost + perplexity_cost}")
    print("")
    print("~~~~ NEXT PROMPT ~~~~")
    print("")

  prompt4part2_dict = {
      "forecaster1": all_forecasts[0][1],
      "forecaster2": all_forecasts[1][1],
      "forecaster3": all_forecasts[2][1],
  }

  formatted_prompt4part2 = replace_keys(prompt4part2, prompt4part2_dict)

  print("+++++++++++FINAL PROMPT + ++++++++++++++++")

  prompt4 = prompt4part1 + PROMPT_TEMPLATE + formatted_prompt4part2

  probability, gpt_text, input_cost, output_cost, total_cost = get_forecast(today, client, question_to_forecast, prompt4, summary_report, model)

  forecaster1_weight = 0.2
  forecaster2_weight = 0.2
  forecaster3_weight = 0.2
  forecaster4_weight = 0.4

  weighted_forecast = forecaster1_weight*float(all_forecasts[0][0]) + forecaster2_weight*float(all_forecasts[1][0]) + forecaster3_weight*float(all_forecasts[2][0]) + forecaster4_weight*float(probability)
  weighted_forecast = int(weighted_forecast)
  overall_cost = overall_cost + total_cost

  #create summary strings for comments:
  header_string = f"""
  *This forecast is produced from four separate prompts. The first three produce independent forecasts and reasoning using different prompts, and the fourth reads the reasoning and forecasts fo the first three and produces its own forecast. Then a weighted forecast is produced from the four forecasts as described below. The reasoning shown is that of the fourth forecaster or "Summary Forecaster". See [the code](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?usp=sharing) for more info on the prompts used.*

  * *Model used: {model}*
  * *Weighted formula: ({forecaster1_weight})(Forecaster A) + ({forecaster2_weight})(Forecaster B) + ({forecaster3_weight})(Forecaster C) + ({forecaster4_weight})(Summary Forecaster)*
  * *Estimated cost of model calls based on tokens (excluding Perplexity info used): ${round(overall_cost,3)}*
  * *Estimated (rough) cost of Perplexity call (if using recent Perplexity search, and including LLM prompt completion): ${round(perplexity_total_cost,3)}*
  * ***Final weighted forecast: {weighted_forecast}%***

  ---

  """
  print(header_string)

  forecasted_count += 1
  if SUBMIT_FORECASTS and weighted_forecast is not None:
    predict(question_to_forecast["id"], float(weighted_forecast))
    comment(question_to_forecast["id"], header_string + "PERPLEXITY\n\n" + summary_report + "\n\n---\n\n" + "GPT\n\n" + gpt_text)

  print(f"Output Reasoning:")
  print(gpt_text)
  print("")
  print("FINAL WEIGHTED FORECAST:")
  print(f"{weighted_forecast}%")
  print("")
  print(f"Overall cost was: ${overall_cost}")
  print("")
  print("################ NEXT QUESTION #################")
  print("")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 26006 Will Trump's lead over Biden be greater than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average?
#
# Here is the prompt used:
#
# You're being asked the following forecasting question:
#
# The question is:
# Will Trump's lead over Biden be greater than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average?
#
# And it has these specific resolution details:
# This question will resolve as Donald Trump's lead over Joe Biden in 538's [national polling average for the 2024 presidential election](https://projects.fivethirtyeight.com/polls/president-general/2024/national/) as reported on the chart for the date of July 15, 2024, when accessed by Metaculus on July 17, 2024.
#
# For the purposes of this question, a positive value means a Trump lead, while a negative value means Biden is leading. For example, as of July 5, 2024, the value reported for July 5 is Trump 2.4 points ahead of Biden, which would be a positive value of 2.4 for this purposes of this question.
#
# Fine print:
# * If the figure for July 15 is not available on July 17 when accessed by Metaculus it will resolve as the value for July 15 when Metaculus is first able to access it. If Metaculus cannot access the figure for July 15 before July 23 the question will be **annulled**.
# * If Trump's polling lead is below the lower bound or above the upper bound, the question will resolve as outside the respective bound.
#
# To get the latest news that will help you forecast on the question, you need to ask your web search tool one question that would be most valuable to help you forecast
# on this question. The question should be posed so that the web search tool will provide you with the most recent information, including the latest information on the progress toward
# the criteria in the forecasting question being met. Please complete the sentence below with the most valuable question to ask:
#
# "What is the most recent news available and prior occurrences related to. . . "
#
#
# No probability found in the text! Skipping!
# The completed question posed to perplexity reads: "What is the most recent news available and prior occurrences related to the 2024 presidential election polling between Donald Trump and Joe Biden?"
# Generated research from perplexity:
# The most recent news available and prior occurrences related to the 2024 presidential election polling between Donald Trump and Joe Biden are as follows:
#
# - **Current Polling**: A recent national poll by Emerson College found that Donald Trump holds a 3-point lead over Joe Biden, with Trump at 46% and Biden at 43%. When undecided voters were pressed to reveal their inclinations, the split was equal, with 50% favoring Trump and 50% favoring Biden.
#
# - **Trump's Lead**: Trump's support has remained steady at 46% since before the initial presidential debate, while Biden's backing has dropped by two percentage points. There has been a significant shift away from Biden among independent voters, who now favor Trump 42% to 38%.
#
# - **Hypothetical Matchups**: In hypothetical one-on-one contests, Trump leads against Vice President Harris (49% to 43%) and other potential substitutes for Biden, including Senator Bernie Sanders (48% to 42%) and California Governor Gavin Newsom (48% to 40%).
#
# - **Biden's Response**: Despite some Democrats advocating for Biden to step down from the race, the president has stood firm on his decision to stay in the running. He has emphasized the need to quell any internal party conflicts and has urged an end to internal discord within the party.
#
# - **NATO Summit**: The NATO summit in Washington, DC, is underway, where President Biden aims to reassure global leaders regarding the alliance's future and his leadership role. This event serves as an opportunity for Biden to demonstrate his capability to handle the rigors of the presidency effectively.
#
# - **Trump's Campaign**: Trump is set to resume his campaign activities at his prominent Miami golf resort, adding an element of suspense to the upcoming election. His close aides and allies remain uncertain about his choice for a running mate.
#
# - **Democratic Support**: Despite internal party disagreements, House Democrats predominantly stand by Biden's bid for re-election. Many prominent Democrats, including former House Speaker Nancy Pelosi, have expressed optimism about Biden's presidential prospects.
# Total perplexity call cost: $0.005585
#
# Here is the prompt used:
#
# You are a professional forecaster interviewing for a job. The interviewer is also a professional forecaster, with a strong track record of accurate forecasts of the future.
# They will ask you a question, and your task is to provide the most accurate forecast you can. To do this, you evaluate past data and trends carefully, make use of comparison classes
# of similar events, take into account base rates about how past events unfolded, and outline the best reasons for and against any particular outcome.
# You know that great forecasters don't just forecast according to the "vibe" of the question and the considerations.
# Instead, they think about the question in a structured way, recording their reasoning as they go,
# and they always consider multiple perspectives that usually give different conclusions, which they reason about together.
# You can't know the future, and the interviewer knows that, so you do not need to hedge your uncertainty, you are simply trying to give
# the most accurate numbers that will be evaluated when the events later unfold.
#
#
#
# The question is:
# Will Trump's lead over Biden be greater than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average?
#
# Here are details about how the outcome of the question will be determined, make sure your forecast is consistent with these:
# This question will resolve as Donald Trump's lead over Joe Biden in 538's [national polling average for the 2024 presidential election](https://projects.fivethirtyeight.com/polls/president-general/2024/national/) as reported on the chart for the date of July 15, 2024, when accessed by Metaculus on July 17, 2024.
#
# For the purposes of this question, a positive value means a Trump lead, while a negative value means Biden is leading. For example, as of July 5, 2024, the value reported for July 5 is Trump 2.4 points ahead of Biden, which would be a positive value of 2.4 for this purposes of this question.
#
# Here is the question's fine print that you need to be consistent with in your forecast:
# * If the figure for July 15 is not available on July 17 when accessed by Metaculus it will resolve as the value for July 15 when Metaculus is first able to access it. If Metaculus cannot access the figure for July 15 before July 23 the question will be **annulled**.
# * If Trump's polling lead is below the lower bound or above the upper bound, the question will resolve as outside the respective bound.
#
# Here is some background of the question, though note that some of the details may be out of date:
# On June 27, 2024, Joe Biden and Donald Trump held their first debate as part of the campaign for the 2024 presidential election. Biden's debate performance was [widely seen as poor](https://projects.fivethirtyeight.com/biden-trump-june-debate-poll/), and prompted calls for Biden to drop out, including [from the New York Times editorial board](https://www.nytimes.com/2024/06/28/opinion/biden-election-debate-trump.html) and, as of July 5, [three House Democrats](https://thehill.com/homenews/house/4755497-seth-moulton-biden-presidential-race/).
#
# The Biden team has reportedly been [taking action](https://www.cnn.com/2024/07/04/politics/biden-rising-tide-pressure-reelection-bid-analysis/index.html) to reverse recent perceptions, and has [so far insisted](https://thehill.com/homenews/campaign/4754840-biden-campaign-denies-dropout-rumors/) that Biden will not be dropping out. However, the New York Times [reported](https://www.nytimes.com/2024/07/03/us/politics/biden-withdraw-election-debate.html) that the Biden team has internally acknowledged that they must turn perceptions around quickly.
#
# According to [538's presidential polling average](https://projects.fivethirtyeight.com/polls/president-general/2024/national/) (when accessed on July 5, 2024), on the date of the debate Trump held a +0.2 percentage point lead in the polling averages, which has since widened to a +2.4 percentage point lead for Trump reported for July 5. The near-term polling trend may be critical as Biden weighs whether to stay in the race ahead of the [2024 Democratic National Convention](https://en.wikipedia.org/wiki/2024_Democratic_National_Convention), which is scheduled to be held August 19th through the 22nd.
#
# Your research assistant provides the following information that is likely more up to date:
# The most recent news available and prior occurrences related to the 2024 presidential election polling between Donald Trump and Joe Biden are as follows:
#
# - **Current Polling**: A recent national poll by Emerson College found that Donald Trump holds a 3-point lead over Joe Biden, with Trump at 46% and Biden at 43%. When undecided voters were pressed to reveal their inclinations, the split was equal, with 50% favoring Trump and 50% favoring Biden.
#
# - **Trump's Lead**: Trump's support has remained steady at 46% since before the initial presidential debate, while Biden's backing has dropped by two percentage points. There has been a significant shift away from Biden among independent voters, who now favor Trump 42% to 38%.
#
# - **Hypothetical Matchups**: In hypothetical one-on-one contests, Trump leads against Vice President Harris (49% to 43%) and other potential substitutes for Biden, including Senator Bernie Sanders (48% to 42%) and California Governor Gavin Newsom (48% to 40%).
#
# - **Biden's Response**: Despite some Democrats advocating for Biden to step down from the race, the president has stood firm on his decision to stay in the running. He has emphasized the need to quell any internal party conflicts and has urged an end to internal discord within the party.
#
# - **NATO Summit**: The NATO summit in Washington, DC, is underway, where President Biden aims to reassure global leaders regarding the alliance's future and his leadership role. This event serves as an opportunity for Biden to demonstrate his capability to handle the rigors of the presidency effectively.
#
# - **Trump's Campaign**: Trump is set to resume his campaign activities at his prominent Miami golf resort, adding an element of suspense to the upcoming election. His close aides and allies remain uncertain about his choice for a running mate.
#
# - **Democratic Support**: Despite internal party disagreements, House Democrats predominantly stand by Biden's bid for re-election. Many prominent Democrats, including former House Speaker Nancy Pelosi, have expressed optimism about Biden's presidential prospects.
#
# Today is 2024-07-09.
#
# Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
#
#
# The extracted probability is: 60%
# Output Reasoning:
# To make an accurate forecast regarding Trump's lead over Biden in 538's national polling average on July 15, 2024, I will analyze past data, current trends, and projected developments.
#
# ### Step-by-Step Reasoning:
#
# 1. **Current Polling Data**:
#    - As of July 5, Trump had a +2.4 lead according to 538's presidential polling average.
#    - A recent Emerson College poll shows Trump had a 3-point lead over Biden.
#
# 2. **Trend Analysis**:
#    - Trump's lead increased from +0.2 on the debate date to +2.4 by July 5.
#    - The Emerson College poll shows a stable support level for Trump (46%) and a slight decline for Biden.
#
# 3. **Potential Influences**:
#    - **Biden's Performance**: Biden's poor debate performance and the handling of subsequent fallout are key factors. His team is trying to reverse perceptions, but there has been significant criticism and some Democratic calls for him to drop out.
#    - **Biden's Firm Stance**: Despite the pressure, Biden remains firm that he will not step down.
#    - **External Events**: The NATO summit could potentially boost Biden's perception if he handles it well, but this effect would need to be significant and quick to impact the July 15 polling average.
#    - **Independents Shifting**: A shift among independent voters away from Biden is significant because independents often swing elections.
#
# 4. **Base Rates and Historic Context**:
#    - Historically, polling averages can swing significantly based on external events and media narratives.
#    - However, in the short term (a week), polling averages tend to move gradually unless there is a major unexpected event.
#
# 5. **Comparison Classes**:
#    - Previous election cycles show that post-debate polling impacts tend to stabilize after about a week unless exacerbated by new developments.
#
# 6. **Key Considerations**:
#    - **For**:
#      - If Biden's team successfully manages the fallout and he performs well at the NATO summit, there may be some recovery, but likely modest.
#      - Democratic support within the party, especially from prominent figures, might help stabilize Biden's polling.
#    - **Against**:
#      - Continued negative media coverage and internal party conflict could keep Trump's lead stable or even increase it.
#      - The stable support for Trump and the shift of independents towards Trump in the recent Emerson poll suggests the lead could remain or widen slightly.
#
# ### Conclusion:
# Given the current trends, the slight but steady growth in Trump's lead, and the potential for Biden to stabilize but not rapidly recover, I assess the likelihood that Trump's lead will be more than 2 and less than or equal to 4 between July 9 and July 15.
#
# **Forecast**:
# The probability that Trump's lead over Biden will be more than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average is assessed to be around 60%. This represents a middle-of-the-road scenario accounting for the stability of current trends and the possibility of limited short-term recovery from Biden's team.
#
# **Final Answer**:
# **Probability: 60%**
# Input cost: $0.007255
# Output cost: $0.009855000000000001
# Total cost: $0.01711
# Perplexity search costs (including LLM prompt completion): $0.008029999999999999
#
# ~~~~ NEXT PROMPT ~~~~
#
#
# Here is the prompt used:
#
# You are a professional forecaster being tested on your skill. You are being asked a question for which you must provide the most accurate forecast you can.
# Reason step by step about the best forecast, carefully considering the information you are presented with and the potential that some of the
# background information and information provided by your research assistant may be out of date or conflicting.
# You also know that a key forecasting practice is to consider the outside view, thinking carefully about reference classes and base rates and how often similar events
# have happened in the past.
#
#
#
# The question is:
# Will Trump's lead over Biden be greater than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average?
#
# Here are details about how the outcome of the question will be determined, make sure your forecast is consistent with these:
# This question will resolve as Donald Trump's lead over Joe Biden in 538's [national polling average for the 2024 presidential election](https://projects.fivethirtyeight.com/polls/president-general/2024/national/) as reported on the chart for the date of July 15, 2024, when accessed by Metaculus on July 17, 2024.
#
# For the purposes of this question, a positive value means a Trump lead, while a negative value means Biden is leading. For example, as of July 5, 2024, the value reported for July 5 is Trump 2.4 points ahead of Biden, which would be a positive value of 2.4 for this purposes of this question.
#
# Here is the question's fine print that you need to be consistent with in your forecast:
# * If the figure for July 15 is not available on July 17 when accessed by Metaculus it will resolve as the value for July 15 when Metaculus is first able to access it. If Metaculus cannot access the figure for July 15 before July 23 the question will be **annulled**.
# * If Trump's polling lead is below the lower bound or above the upper bound, the question will resolve as outside the respective bound.
#
# Here is some background of the question, though note that some of the details may be out of date:
# On June 27, 2024, Joe Biden and Donald Trump held their first debate as part of the campaign for the 2024 presidential election. Biden's debate performance was [widely seen as poor](https://projects.fivethirtyeight.com/biden-trump-june-debate-poll/), and prompted calls for Biden to drop out, including [from the New York Times editorial board](https://www.nytimes.com/2024/06/28/opinion/biden-election-debate-trump.html) and, as of July 5, [three House Democrats](https://thehill.com/homenews/house/4755497-seth-moulton-biden-presidential-race/).
#
# The Biden team has reportedly been [taking action](https://www.cnn.com/2024/07/04/politics/biden-rising-tide-pressure-reelection-bid-analysis/index.html) to reverse recent perceptions, and has [so far insisted](https://thehill.com/homenews/campaign/4754840-biden-campaign-denies-dropout-rumors/) that Biden will not be dropping out. However, the New York Times [reported](https://www.nytimes.com/2024/07/03/us/politics/biden-withdraw-election-debate.html) that the Biden team has internally acknowledged that they must turn perceptions around quickly.
#
# According to [538's presidential polling average](https://projects.fivethirtyeight.com/polls/president-general/2024/national/) (when accessed on July 5, 2024), on the date of the debate Trump held a +0.2 percentage point lead in the polling averages, which has since widened to a +2.4 percentage point lead for Trump reported for July 5. The near-term polling trend may be critical as Biden weighs whether to stay in the race ahead of the [2024 Democratic National Convention](https://en.wikipedia.org/wiki/2024_Democratic_National_Convention), which is scheduled to be held August 19th through the 22nd.
#
# Your research assistant provides the following information that is likely more up to date:
# The most recent news available and prior occurrences related to the 2024 presidential election polling between Donald Trump and Joe Biden are as follows:
#
# - **Current Polling**: A recent national poll by Emerson College found that Donald Trump holds a 3-point lead over Joe Biden, with Trump at 46% and Biden at 43%. When undecided voters were pressed to reveal their inclinations, the split was equal, with 50% favoring Trump and 50% favoring Biden.
#
# - **Trump's Lead**: Trump's support has remained steady at 46% since before the initial presidential debate, while Biden's backing has dropped by two percentage points. There has been a significant shift away from Biden among independent voters, who now favor Trump 42% to 38%.
#
# - **Hypothetical Matchups**: In hypothetical one-on-one contests, Trump leads against Vice President Harris (49% to 43%) and other potential substitutes for Biden, including Senator Bernie Sanders (48% to 42%) and California Governor Gavin Newsom (48% to 40%).
#
# - **Biden's Response**: Despite some Democrats advocating for Biden to step down from the race, the president has stood firm on his decision to stay in the running. He has emphasized the need to quell any internal party conflicts and has urged an end to internal discord within the party.
#
# - **NATO Summit**: The NATO summit in Washington, DC, is underway, where President Biden aims to reassure global leaders regarding the alliance's future and his leadership role. This event serves as an opportunity for Biden to demonstrate his capability to handle the rigors of the presidency effectively.
#
# - **Trump's Campaign**: Trump is set to resume his campaign activities at his prominent Miami golf resort, adding an element of suspense to the upcoming election. His close aides and allies remain uncertain about his choice for a running mate.
#
# - **Democratic Support**: Despite internal party disagreements, House Democrats predominantly stand by Biden's bid for re-election. Many prominent Democrats, including former House Speaker Nancy Pelosi, have expressed optimism about Biden's presidential prospects.
#
# Today is 2024-07-09.
#
# Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
#
#
# The extracted probability is: 70%
# Output Reasoning:
# To forecast whether Trump's lead over Biden will be greater than 2 and less than or equal to 4 points on July 15, 2024, according to 538's national polling average, we need to consider both historical context and current trends. Here is the step-by-step reasoning to arrive at the forecast:
#
# ### Step 1: Reviewing the Base Rates and Historical Context
# 1. **Historical Election Poll Trends:** Historically, polling fluctuations do occur, especially during election years due to events such as debates, conventions, and major news. However, substantial shifts are less common without significant political events.
# 2. **Typical Poll Movements Post-Debate:** After key debates, presidents’ poll numbers may shift based on their performance. Biden's poor debate performance indeed had a noticeable impact, but the continued trend depends on his subsequent actions and the responses from voters.
# 3. **Polling Averages Stability:** 538's national polling average tends to smooth out individual poll variations, indicating a more stable trend rather than fluctuations from single events.
#
# ### Step 2: Considering Current Data and Events
#
# 1. **Current Polling Data:** As of July 9, 2024, Trump holds a 3-point lead according to the latest Emerson College poll. Previously, the 538 polling average had Trump at a 2.4-point lead on July 5. The trend is upward for Trump but remains close to the target range of 2 to 4 points.
# 2. **Key Recent Events:**
#    - Biden’s poor debate performance and subsequent media coverage.
#    - Calls for Biden to drop out and internal party conflicts.
#    - Biden’s counter-efforts to rally support and his upcoming participation in the NATO summit, which might influence public perception positively.
#
# ### Step 3: Examining Upcoming Influences
# 1. **Upcoming Democratic National Convention:** The convention might still be over a month away, but any major announcements or strategic shifts could influence polling.
# 2. **NATO Summit:** Biden’s performance here might help recover some of his standing among undecided or wavering voters.
# 3. **Trump’s Campaign Activities:** Trump's campaign activities, revitalized by his rallies, can continue to consolidate his lead, particularly if Biden does not manage to change the narrative.
#
# ### Step 4: Considering Uncertainties and Potential for Conflicting Information
# - The potential for new developments or unexpected events that could sway voter opinions dramatically.
# - The inherent uncertainty in polling data, where margins of error and respondent biases might not fully capture the true state of voter preferences.
#
# ### Step 5: Calculating the Probability
# 1. **Stability Analysis:** The trend from +2.4 to +3.0 is indicative of a potential stabilization within the 2 to 4 point range.
# 2. **Potential Recovery:** Biden’s efforts, particularly the NATO summit, might marginally improve his polling numbers but are unlikely to drastically change the trajectory before July 15.
# 3. **Trend Continuation:** Assuming the current trend continues, Trump's lead is likely to remain within the specific range given Biden's campaign challenges and the limited time remaining.
#
# Combining the analysis of historical trends, current polling data, recent and upcoming events, and accounting for potential uncertainties, it is reasonable to estimate the probability that Trump's lead will be greater than 2 but less than or equal to 4 on July 15, 2024, as follows:
#
# **Probability: 70%**
#
# This estimate considers the likely continuation of the current trend while allowing for minor adjustments that could still keep Trump’s lead within the specified range.
# Input cost: $0.006790000000000001
# Output cost: $0.010815
# Total cost: $0.017605000000000003
# Perplexity search costs (including LLM prompt completion): $0.008029999999999999
#
# ~~~~ NEXT PROMPT ~~~~
#
#
# Here is the prompt used:
#
# You are a professional forecaster trying your best to produce an accurate forecast for the question below. You have a keen eye for detail, and know that
# the resolution criteria and fine print of a question often contain important edge cases that should be considered. You also know that rookie forecasters
# tend to be underconfident, and so your forecasts should be confident and extremize some of the way toward 1% or 99%. You're also aware that forecasting questions tend
# to be biased, so when forecasting questions asks about things that would be a departure from the norm or from business as usual, those things tend not to happen.
# You will use that knowledge to make the best forecast you can, and describe your reasoning step by step.
#
#
#
# The question is:
# Will Trump's lead over Biden be greater than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average?
#
# Here are details about how the outcome of the question will be determined, make sure your forecast is consistent with these:
# This question will resolve as Donald Trump's lead over Joe Biden in 538's [national polling average for the 2024 presidential election](https://projects.fivethirtyeight.com/polls/president-general/2024/national/) as reported on the chart for the date of July 15, 2024, when accessed by Metaculus on July 17, 2024.
#
# For the purposes of this question, a positive value means a Trump lead, while a negative value means Biden is leading. For example, as of July 5, 2024, the value reported for July 5 is Trump 2.4 points ahead of Biden, which would be a positive value of 2.4 for this purposes of this question.
#
# Here is the question's fine print that you need to be consistent with in your forecast:
# * If the figure for July 15 is not available on July 17 when accessed by Metaculus it will resolve as the value for July 15 when Metaculus is first able to access it. If Metaculus cannot access the figure for July 15 before July 23 the question will be **annulled**.
# * If Trump's polling lead is below the lower bound or above the upper bound, the question will resolve as outside the respective bound.
#
# Here is some background of the question, though note that some of the details may be out of date:
# On June 27, 2024, Joe Biden and Donald Trump held their first debate as part of the campaign for the 2024 presidential election. Biden's debate performance was [widely seen as poor](https://projects.fivethirtyeight.com/biden-trump-june-debate-poll/), and prompted calls for Biden to drop out, including [from the New York Times editorial board](https://www.nytimes.com/2024/06/28/opinion/biden-election-debate-trump.html) and, as of July 5, [three House Democrats](https://thehill.com/homenews/house/4755497-seth-moulton-biden-presidential-race/).
#
# The Biden team has reportedly been [taking action](https://www.cnn.com/2024/07/04/politics/biden-rising-tide-pressure-reelection-bid-analysis/index.html) to reverse recent perceptions, and has [so far insisted](https://thehill.com/homenews/campaign/4754840-biden-campaign-denies-dropout-rumors/) that Biden will not be dropping out. However, the New York Times [reported](https://www.nytimes.com/2024/07/03/us/politics/biden-withdraw-election-debate.html) that the Biden team has internally acknowledged that they must turn perceptions around quickly.
#
# According to [538's presidential polling average](https://projects.fivethirtyeight.com/polls/president-general/2024/national/) (when accessed on July 5, 2024), on the date of the debate Trump held a +0.2 percentage point lead in the polling averages, which has since widened to a +2.4 percentage point lead for Trump reported for July 5. The near-term polling trend may be critical as Biden weighs whether to stay in the race ahead of the [2024 Democratic National Convention](https://en.wikipedia.org/wiki/2024_Democratic_National_Convention), which is scheduled to be held August 19th through the 22nd.
#
# Your research assistant provides the following information that is likely more up to date:
# The most recent news available and prior occurrences related to the 2024 presidential election polling between Donald Trump and Joe Biden are as follows:
#
# - **Current Polling**: A recent national poll by Emerson College found that Donald Trump holds a 3-point lead over Joe Biden, with Trump at 46% and Biden at 43%. When undecided voters were pressed to reveal their inclinations, the split was equal, with 50% favoring Trump and 50% favoring Biden.
#
# - **Trump's Lead**: Trump's support has remained steady at 46% since before the initial presidential debate, while Biden's backing has dropped by two percentage points. There has been a significant shift away from Biden among independent voters, who now favor Trump 42% to 38%.
#
# - **Hypothetical Matchups**: In hypothetical one-on-one contests, Trump leads against Vice President Harris (49% to 43%) and other potential substitutes for Biden, including Senator Bernie Sanders (48% to 42%) and California Governor Gavin Newsom (48% to 40%).
#
# - **Biden's Response**: Despite some Democrats advocating for Biden to step down from the race, the president has stood firm on his decision to stay in the running. He has emphasized the need to quell any internal party conflicts and has urged an end to internal discord within the party.
#
# - **NATO Summit**: The NATO summit in Washington, DC, is underway, where President Biden aims to reassure global leaders regarding the alliance's future and his leadership role. This event serves as an opportunity for Biden to demonstrate his capability to handle the rigors of the presidency effectively.
#
# - **Trump's Campaign**: Trump is set to resume his campaign activities at his prominent Miami golf resort, adding an element of suspense to the upcoming election. His close aides and allies remain uncertain about his choice for a running mate.
#
# - **Democratic Support**: Despite internal party disagreements, House Democrats predominantly stand by Biden's bid for re-election. Many prominent Democrats, including former House Speaker Nancy Pelosi, have expressed optimism about Biden's presidential prospects.
#
# Today is 2024-07-09.
#
# Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
#
#
# The extracted probability is: 80%
# Output Reasoning:
# To produce an accurate forecast for whether Trump's lead over Biden will be greater than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average, we need to carefully assess the information provided and consider historical trends, recent polling data, and election dynamics. Here's the step-by-step analysis:
#
# ### Step 1: Current Polling Data and Trends
# - **Emerson College Poll**: Trump holds a 3-point lead over Biden.
# - **538 Data on July 5**: Trump has a +2.4 percentage point lead.
# - **Overall Trend**: Trump's lead has been increasing since the debated, reflecting a decline in Biden's support, particularly among independents.
#
# ### Step 2: Analysis of Political Context
# - **Biden's Debate Performance**: Widely seen as poor, leading to speculation and calls for him to drop out.
# - **Democratic Support**: Despite some internal disagreements, prominent Democrats still support Biden.
# - **Trump's Campaign**: Steady polling numbers and resumption of campaign activities.
#
# ### Step 3: Impact of Major Events
# - **NATO Summit**: Biden is trying to demonstrate his leadership abilities, which could positively affect his standing if perceived as successful.
# - **Biden's Firmness**: Biden remains firm on staying in the race, which might stabilize his support base to some extent.
#
# ### Step 4: Historical Context and Bias
# - **Incumbent Performance**: Incumbents often face fluctuations but generally maintain a solid support base.
# - **Forecasting Bias**: Forecasting questions tend to be biased towards 'business as usual.' Significant deviations (e.g., Biden dropping out or a dramatic change in polling) are less likely.
#
# ### Step 5: Probabilistic Reasoning
# Given the current data and trends:
# - **Trump's lead has been growing**, but it fits within a small range (e.g., 2.4 points on July 5 and 3 points in the recent Emerson poll).
# - **538's historical adjustments** tend to smooth out day-to-day fluctuations, making a +/-1.6 points change relatively stable in the short term and fit within that narrow band.
#
# Given Trump's current lead and the political situation:
# 1. The probability of Trump’s lead being **greater than 2 and less than or equal to 4** is reasonably high. While a small deviation might occur, it is unlikely to be dramatic given the context.
# 2. Trump’s lead staying within the 2 to 4 range is the most probable scenario, considering recent trends and the small range of fluctuation observed.
#
# Thus, incorporating confidences as advised, I extremize the probability slightly towards higher confidence:
#
# ### Final Answer:
# **Probability: 80%**
# Input cost: $0.007
# Output cost: $0.008505
# Total cost: $0.015505000000000001
# Perplexity search costs (including LLM prompt completion): $0.008029999999999999
#
# ~~~~ NEXT PROMPT ~~~~
#
# +++++++++++FINAL PROMPT + ++++++++++++++++
#
# Here is the prompt used:
#
# You are a professional forecaster trying your best to produce an accurate forecast for the question below.
#
#
#
# The question is:
# Will Trump's lead over Biden be greater than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average?
#
# Here are details about how the outcome of the question will be determined, make sure your forecast is consistent with these:
# This question will resolve as Donald Trump's lead over Joe Biden in 538's [national polling average for the 2024 presidential election](https://projects.fivethirtyeight.com/polls/president-general/2024/national/) as reported on the chart for the date of July 15, 2024, when accessed by Metaculus on July 17, 2024.
#
# For the purposes of this question, a positive value means a Trump lead, while a negative value means Biden is leading. For example, as of July 5, 2024, the value reported for July 5 is Trump 2.4 points ahead of Biden, which would be a positive value of 2.4 for this purposes of this question.
#
# Here is the question's fine print that you need to be consistent with in your forecast:
# * If the figure for July 15 is not available on July 17 when accessed by Metaculus it will resolve as the value for July 15 when Metaculus is first able to access it. If Metaculus cannot access the figure for July 15 before July 23 the question will be **annulled**.
# * If Trump's polling lead is below the lower bound or above the upper bound, the question will resolve as outside the respective bound.
#
# Here is some background of the question, though note that some of the details may be out of date:
# On June 27, 2024, Joe Biden and Donald Trump held their first debate as part of the campaign for the 2024 presidential election. Biden's debate performance was [widely seen as poor](https://projects.fivethirtyeight.com/biden-trump-june-debate-poll/), and prompted calls for Biden to drop out, including [from the New York Times editorial board](https://www.nytimes.com/2024/06/28/opinion/biden-election-debate-trump.html) and, as of July 5, [three House Democrats](https://thehill.com/homenews/house/4755497-seth-moulton-biden-presidential-race/).
#
# The Biden team has reportedly been [taking action](https://www.cnn.com/2024/07/04/politics/biden-rising-tide-pressure-reelection-bid-analysis/index.html) to reverse recent perceptions, and has [so far insisted](https://thehill.com/homenews/campaign/4754840-biden-campaign-denies-dropout-rumors/) that Biden will not be dropping out. However, the New York Times [reported](https://www.nytimes.com/2024/07/03/us/politics/biden-withdraw-election-debate.html) that the Biden team has internally acknowledged that they must turn perceptions around quickly.
#
# According to [538's presidential polling average](https://projects.fivethirtyeight.com/polls/president-general/2024/national/) (when accessed on July 5, 2024), on the date of the debate Trump held a +0.2 percentage point lead in the polling averages, which has since widened to a +2.4 percentage point lead for Trump reported for July 5. The near-term polling trend may be critical as Biden weighs whether to stay in the race ahead of the [2024 Democratic National Convention](https://en.wikipedia.org/wiki/2024_Democratic_National_Convention), which is scheduled to be held August 19th through the 22nd.
#
# Your research assistant provides the following information that is likely more up to date:
# The most recent news available and prior occurrences related to the 2024 presidential election polling between Donald Trump and Joe Biden are as follows:
#
# - **Current Polling**: A recent national poll by Emerson College found that Donald Trump holds a 3-point lead over Joe Biden, with Trump at 46% and Biden at 43%. When undecided voters were pressed to reveal their inclinations, the split was equal, with 50% favoring Trump and 50% favoring Biden.
#
# - **Trump's Lead**: Trump's support has remained steady at 46% since before the initial presidential debate, while Biden's backing has dropped by two percentage points. There has been a significant shift away from Biden among independent voters, who now favor Trump 42% to 38%.
#
# - **Hypothetical Matchups**: In hypothetical one-on-one contests, Trump leads against Vice President Harris (49% to 43%) and other potential substitutes for Biden, including Senator Bernie Sanders (48% to 42%) and California Governor Gavin Newsom (48% to 40%).
#
# - **Biden's Response**: Despite some Democrats advocating for Biden to step down from the race, the president has stood firm on his decision to stay in the running. He has emphasized the need to quell any internal party conflicts and has urged an end to internal discord within the party.
#
# - **NATO Summit**: The NATO summit in Washington, DC, is underway, where President Biden aims to reassure global leaders regarding the alliance's future and his leadership role. This event serves as an opportunity for Biden to demonstrate his capability to handle the rigors of the presidency effectively.
#
# - **Trump's Campaign**: Trump is set to resume his campaign activities at his prominent Miami golf resort, adding an element of suspense to the upcoming election. His close aides and allies remain uncertain about his choice for a running mate.
#
# - **Democratic Support**: Despite internal party disagreements, House Democrats predominantly stand by Biden's bid for re-election. Many prominent Democrats, including former House Speaker Nancy Pelosi, have expressed optimism about Biden's presidential prospects.
#
# Today is 2024-07-09.
#
# Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
#
# Now that you know what the question asks and some relevant background and research, your job is to make the best forecast you can. You know that examining the reasoning of other
# forecasters is an excellent way to improve your own forecast. Below I have provided the reasoning from three other forecasters who predicted on the same question.
# Examine their reasoning and use it to inform your own, using your expertise as a forecaster to assess which reasoning seems strongest and which seems flawed,
# as well as which reasoning seems to incorporate the most accurate information about base rates and historic reference classes. Construct your own reasoning and forecast,
# describing your reasoning step by step and incorporating the strongest arguments from the other forecasters in a way that improves your own reasoning. First produce a
# one sentence summary of the reasoning of each forecaster (repeating the final probability each predicted), then describe your forecast.
#
# Forecaster A:
# To make an accurate forecast regarding Trump's lead over Biden in 538's national polling average on July 15, 2024, I will analyze past data, current trends, and projected developments.
#
# ### Step-by-Step Reasoning:
#
# 1. **Current Polling Data**:
#    - As of July 5, Trump had a +2.4 lead according to 538's presidential polling average.
#    - A recent Emerson College poll shows Trump had a 3-point lead over Biden.
#
# 2. **Trend Analysis**:
#    - Trump's lead increased from +0.2 on the debate date to +2.4 by July 5.
#    - The Emerson College poll shows a stable support level for Trump (46%) and a slight decline for Biden.
#
# 3. **Potential Influences**:
#    - **Biden's Performance**: Biden's poor debate performance and the handling of subsequent fallout are key factors. His team is trying to reverse perceptions, but there has been significant criticism and some Democratic calls for him to drop out.
#    - **Biden's Firm Stance**: Despite the pressure, Biden remains firm that he will not step down.
#    - **External Events**: The NATO summit could potentially boost Biden's perception if he handles it well, but this effect would need to be significant and quick to impact the July 15 polling average.
#    - **Independents Shifting**: A shift among independent voters away from Biden is significant because independents often swing elections.
#
# 4. **Base Rates and Historic Context**:
#    - Historically, polling averages can swing significantly based on external events and media narratives.
#    - However, in the short term (a week), polling averages tend to move gradually unless there is a major unexpected event.
#
# 5. **Comparison Classes**:
#    - Previous election cycles show that post-debate polling impacts tend to stabilize after about a week unless exacerbated by new developments.
#
# 6. **Key Considerations**:
#    - **For**:
#      - If Biden's team successfully manages the fallout and he performs well at the NATO summit, there may be some recovery, but likely modest.
#      - Democratic support within the party, especially from prominent figures, might help stabilize Biden's polling.
#    - **Against**:
#      - Continued negative media coverage and internal party conflict could keep Trump's lead stable or even increase it.
#      - The stable support for Trump and the shift of independents towards Trump in the recent Emerson poll suggests the lead could remain or widen slightly.
#
# ### Conclusion:
# Given the current trends, the slight but steady growth in Trump's lead, and the potential for Biden to stabilize but not rapidly recover, I assess the likelihood that Trump's lead will be more than 2 and less than or equal to 4 between July 9 and July 15.
#
# **Forecast**:
# The probability that Trump's lead over Biden will be more than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average is assessed to be around 60%. This represents a middle-of-the-road scenario accounting for the stability of current trends and the possibility of limited short-term recovery from Biden's team.
#
# **Final Answer**:
# **Probability: 60%**
#
# Forecaster B:
# To forecast whether Trump's lead over Biden will be greater than 2 and less than or equal to 4 points on July 15, 2024, according to 538's national polling average, we need to consider both historical context and current trends. Here is the step-by-step reasoning to arrive at the forecast:
#
# ### Step 1: Reviewing the Base Rates and Historical Context
# 1. **Historical Election Poll Trends:** Historically, polling fluctuations do occur, especially during election years due to events such as debates, conventions, and major news. However, substantial shifts are less common without significant political events.
# 2. **Typical Poll Movements Post-Debate:** After key debates, presidents’ poll numbers may shift based on their performance. Biden's poor debate performance indeed had a noticeable impact, but the continued trend depends on his subsequent actions and the responses from voters.
# 3. **Polling Averages Stability:** 538's national polling average tends to smooth out individual poll variations, indicating a more stable trend rather than fluctuations from single events.
#
# ### Step 2: Considering Current Data and Events
#
# 1. **Current Polling Data:** As of July 9, 2024, Trump holds a 3-point lead according to the latest Emerson College poll. Previously, the 538 polling average had Trump at a 2.4-point lead on July 5. The trend is upward for Trump but remains close to the target range of 2 to 4 points.
# 2. **Key Recent Events:**
#    - Biden’s poor debate performance and subsequent media coverage.
#    - Calls for Biden to drop out and internal party conflicts.
#    - Biden’s counter-efforts to rally support and his upcoming participation in the NATO summit, which might influence public perception positively.
#
# ### Step 3: Examining Upcoming Influences
# 1. **Upcoming Democratic National Convention:** The convention might still be over a month away, but any major announcements or strategic shifts could influence polling.
# 2. **NATO Summit:** Biden’s performance here might help recover some of his standing among undecided or wavering voters.
# 3. **Trump’s Campaign Activities:** Trump's campaign activities, revitalized by his rallies, can continue to consolidate his lead, particularly if Biden does not manage to change the narrative.
#
# ### Step 4: Considering Uncertainties and Potential for Conflicting Information
# - The potential for new developments or unexpected events that could sway voter opinions dramatically.
# - The inherent uncertainty in polling data, where margins of error and respondent biases might not fully capture the true state of voter preferences.
#
# ### Step 5: Calculating the Probability
# 1. **Stability Analysis:** The trend from +2.4 to +3.0 is indicative of a potential stabilization within the 2 to 4 point range.
# 2. **Potential Recovery:** Biden’s efforts, particularly the NATO summit, might marginally improve his polling numbers but are unlikely to drastically change the trajectory before July 15.
# 3. **Trend Continuation:** Assuming the current trend continues, Trump's lead is likely to remain within the specific range given Biden's campaign challenges and the limited time remaining.
#
# Combining the analysis of historical trends, current polling data, recent and upcoming events, and accounting for potential uncertainties, it is reasonable to estimate the probability that Trump's lead will be greater than 2 but less than or equal to 4 on July 15, 2024, as follows:
#
# **Probability: 70%**
#
# This estimate considers the likely continuation of the current trend while allowing for minor adjustments that could still keep Trump’s lead within the specified range.
#
# Forecaster C:
# To produce an accurate forecast for whether Trump's lead over Biden will be greater than 2 and less than or equal to 4 on July 15, 2024, according to 538's national polling average, we need to carefully assess the information provided and consider historical trends, recent polling data, and election dynamics. Here's the step-by-step analysis:
#
# ### Step 1: Current Polling Data and Trends
# - **Emerson College Poll**: Trump holds a 3-point lead over Biden.
# - **538 Data on July 5**: Trump has a +2.4 percentage point lead.
# - **Overall Trend**: Trump's lead has been increasing since the debated, reflecting a decline in Biden's support, particularly among independents.
#
# ### Step 2: Analysis of Political Context
# - **Biden's Debate Performance**: Widely seen as poor, leading to speculation and calls for him to drop out.
# - **Democratic Support**: Despite some internal disagreements, prominent Democrats still support Biden.
# - **Trump's Campaign**: Steady polling numbers and resumption of campaign activities.
#
# ### Step 3: Impact of Major Events
# ...
#
# 2. **Poll Finds Biden Damaged by Debate**:
#    - A survey by Bendixen & Amandi reveals that Biden is now slightly behind Trump, with Vice President Kamala Harris and former Secretary of State Hillary Clinton emerging as stronger contenders. The poll highlights a dynamic shift within the Democratic Party, with some Democrats expressing doubts about Biden's fitness to continue.
#
# 3. **Biden Remains Determined**:
#    - Despite calls for him to step aside, Biden remains steadfast in his commitment to the presidential race. He has dismissed concerns about his candidacy, framing his battle for political survival as a clash between "party elites" and ordinary voters.
#
# 4. **Polling Trends**:
#    - National polls show Trump holding a slight edge over Biden, with the gap falling within the margin of error. Post-debate, Biden's deficit has widened by 1 to 2 points in some polls, though this change remains within the margin of error, indicating no significant shift in the race.
#
# 5. **Democratic Support**:
#    - House Democrats predominantly stand by Biden's bid for re-election, with some expressing optimism about his presidential prospects. However, there are also dissenting voices advocating for private discussions to address concerns about Biden's performance.
#
# These developments highlight the ongoing dynamics in the 2024 presidential election, with shifting public perceptions and internal party divisions influencing the race.
#
# Today is 2024-07-09.
#
# Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
#
# Now that you know what the question asks and some relevant background and research, your job is to make the best forecast you can. You know that examining the reasoning of other
# forecasters is an excellent way to improve your own forecast. Below I have provided the reasoning from three other forecasters who predicted on the same question.
# Examine their reasoning and use it to inform your own, using your expertise as a forecaster to assess which reasoning seems strongest and which seems flawed,
# as well as which reasoning seems to incorporate the most accurate information about base rates and historic reference classes. Construct your own reasoning and forecast,
# describing your reasoning step by step and incorporating the strongest arguments from the other forecasters in a way that improves your own reasoning. First produce a
# one sentence summary of the reasoning of each forecaster (repeating the final probability each predicted), then describe your forecast.
#
# Forecaster A:
# To forecast the probability of Trump's lead over Biden being greater than 2 but less than or equal to 3 on July 15, 2024, I will break down my reasoning into several steps, utilizing past data, trends, comparison classes, and base rates.
#
# ### Step 1: Current Polling Data and Trends
# Based on the national polling average from 538 on July 5, 2024, Trump leads Biden by 2.4 percentage points. The recent New York Times/Siena College poll indicates that Trump has widened his lead by six percentage points among likely voters, suggesting a significant shift in Trump's favor following Biden's poor debate performance.
#
# **Trend Analysis**:
# - **Starting Point**: Trump's lead on July 5 is +2.4 points post-debate.
# - **Recent Shift**: The New York Times/Siena poll suggests a further increase in Trump's lead, up to 6 points among likely voters.
#
# ### Step 2: Historical Performance and Comparison Classes
# By comparing similar periods during election cycles:
# 1. **Immediate Post-Debate Effects**: Historically, poorly received debates can rapidly shift polling numbers, as seen in previous elections (e.g., Romney-Obama 2012).
# 2. **Poll Stability**: Polling averages tend to stabilize within a few weeks unless significant new events occur. Thus, the current shift could represent a temporary peak.
#
# ### Step 3: Considering Base Rates
# Examining base rates of polling shifts in similar elections:
# - After significant debate events, leads often increase temporarily but tend to regress partially as immediate reactions diminish and counter-campaign efforts take effect.
# - The average movement range post-debate is around 1-3 points for a similar timeframe (1-2 weeks out).
#
# ### Step 4: Factors For and Against a 2-3 Point Lead
# **For**:
# - Momentum from the debate performance might sustain a 2-3 point lead.
# - Public sentiment and media narratives are currently unfavorable to Biden.
#
# **Against**:
# - Counter-campaigning by Biden's team could mitigate some of the damage.
# - Historical trends suggest that initial drastic shifts often soften as the dust settles.
#
# ### Step 5: Calculating the Final Forecast
# Given the current data (Trump +2.4), a further average shift of possibly 1-2 points based on historical trends and base rates, the most probable scenario is a lead that could range from 2 to 4 points. In terms of probabilities:
#
# 1. **Trump's lead < 2 points**: Unlikely given the momentum.
# 2. **Trump's lead between 2 to 3 points**: Quite plausible considering the current lead and potential additional shifts.
# 3. **Trump's lead > 3 points**: Also plausible but somewhat less likely as counter-campaigning might temper the initial shock.
#
# ### Combining Factors and Final Probability
# - Assume a 50% chance for the mean continuation of trends resulting in a range of 2-3 points.
# - Factor in a 25% chance of less than 2 points and a 25% chance of more than 3 points when considering regression and stronger shifts respectively.
#
# ### Final Probability:
# Considering these perspectives and their probabilities, the final weighted estimate leans towards the lead being within 2-3 points:
#
# **Probability: 45%**
#
# Forecaster B:
# To forecast whether Trump's lead over Biden will be greater than 2 and less than or equal to 3 percentage points on July 15, 2024, according to 538’s national polling average, I’ll follow a structured approach considering both the inside view (detailed, specific information) and the outside view (historical base rates and reference classes).
#
# ### Step-by-Step Reasoning
#
# #### Step 1: Current Polling Situation
# From the information provided:
# - As of June 27, 2024, Trump had a small lead of +0.2 points.
# - As of July 5, 2024, Trump's lead increased to +2.4 points.
# - Recent additional polls suggest that Trump has widened his lead further.
#
# #### Step 2: Trends and Recent Developments
# - **Trend Analysis**: Post-debate, Biden's polling has faced a significant backlash. For example, a New York Times/Siena College poll shows Trump improving his position by six points.
# - **Key Indicators**: Surveys indicate an ongoing trend with Trump taking a more substantial lead, influenced by the debate fallout and increasing questions about Biden's candidacy.
# - **Possible Fluctuations**: Polling changes can be volatile, especially with reactions to recent events (debate performance, internal party dynamics).
#
# #### Step 3: Outside View and Historical Trends
# - **Previous Elections and Polls**: Historically, polling leads can fluctuate based on major events, debates, and candidate performances. However, such changes are usually within a few percentage points.
# - **Mid-July Poll Trends**: For similar past election cycles (e.g., Trump vs. Clinton in 2016, Biden vs. Trump in 2020), mid-year polling averages have shown some stability barring any new, major events.
#
# #### Step 4: Reference Classes
# - It is noteworthy to consider the frequency with which major debate performances lead to significant and lasting changes in polling.
# - Typically, while debates can shift polling by a few percentage points, the effect does often stabilize within 1-2 weeks.
#
# ### Analysis Summarization
# - **Current Average Lead**: +2.4 points (as of July 5).
# - **Post-Debate Influence**: Significant negative impact on Biden's polling.
# - **Trend Continuity**: Current trend suggests the possibility of Trump’s lead slightly widening or remaining stable.
# - **Reference Class**: Polling changes post-major event (debates) usually stabilize within a few points.
#
# Given the above, the most informed projection is that Trump’s lead on July 15 is likely to stay within a slightly wider but not dramatically different margin compared to the current lead. A Trump lead greater than 2 points and up to 3 points is a plausible range, as the lead may not stabilize exactly at +2.4 but could reasonably fall within this band.
#
# ### Probability Estimation
#
# By consolidating the trend data and factoring in potential minor adjustments but not massive fluctuations, we estimate:
#
# - **Probability of Trump's lead > 2 and ≤ 3 on July 15, 2024**: Considering current data and trends, the confidence in this specific range is moderate to high but not absolute.
#
# **Final Answer: Probability: 60%**
#
# This estimate balances the observed trends and typical polling behaviors while allowing for typical polling variations closer to election time.
#
# Forecaster C:
# To arrive at an appropriate probability for whether Trump's lead over Biden will be greater than 2 and less than or equal to 3 on July 15, 2024, let's break down the information step by step:
#
# ### Background Data and Trends Analysis
# 1. **Current Polling Data**:
#    - As of July 5, 2024, Trump is leading Biden by +2.4 percentage points in the national polling average according to 538.
#    - This lead has widened since the first debate, indicating a recent surge in Trump's support following Biden's poor debate performance.
#
# 2. **Polling Trend Information Since the Debate**:
#    - A New York Times/Siena College poll shows Trump has widened his lead by six percentage points among likely voters.
#    - A Bendixen & Amandi survey shows Biden is now slightly behind Trump, with the gap widened post-debate.
#    - National polls generally indicate that Trump's edge over Biden falls within the margin of error, suggesting fluctuating but slightly increasing trends in Trump's favor.
#
# 3. **Political Climate and Upcoming Events**:
#    - Biden remains determined to stay in the race despite increasing pressure to drop out.
#    - The Democratic National Convention is scheduled for August 19-22, which could potentially shift public opinion again.
#
# ### Analysis of Specific Probabilities
# Given the most recent data, it’s important to recognize Trump's current lead and the fluctuation in polling numbers:
#
# - **Greater than 2 points but less than or equal to 3**:
#   - Current data shows Trump at +2.4.
#   - The information provided shows variability but tends to point towards a slight increase in Trump's lead given the post-debate dynamic.
#
# Occam’s razor (simpler explanations are preferable until more evidence is presented) and common forecasting biases (forecasting questions tend to overestimate departures from the norm) imply that unless there's a compelling reason for Biden's polling to change dramatically, it’s likely that percentages will hover near current values.
#
# ### Extremizing Toward Likely Outcomes
# Considering rookie forecasters tend to be underconfident, we need to adjust and extremize our forecast. Given the current lead of +2.4 points, the most likely scenario is that Trump's lead will remain in a similar range:
#
# - **Trump's lead staying in the 2 to 3 range**: Given that it's currently at +2.4 and polling tends to be somewhat stable without major, drastic changes within short periods, especially in such a tight range.
#
# ### Final Probability Calculation
# I consider the trend and extremize slightly towards the broader stable range (2 to 3 points). This stability arises because national polling averages do not typically show massive daily swings without major intervening events, and none are forecasted imminently.
#
# **Final Probability: 80%**
#
# So, my final forecast considering all the factors is:
# **Probability: 80%**
#
#
# The extracted probability is: 65%
#
#   *This forecast is produced from four separate prompts. The first three produce independent forecasts and reasoning using different prompts, and the fourth reads the reasoning and forecasts fo the first three and produces its own forecast. Then a weighted forecast is produced from the four forecasts as described below. The reasoning shown is that of the fourth forecaster or "Summary Forecaster". See [the code](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?usp=sharing) for more info on the prompts used.*
#
#   * *Model used: gpt-4o*
#   * *Weighted formula: (0.2)(Forecaster A) + (0.2)(Forecaster B) + (0.2)(Forecaster C) + (0.4)(Summary Forecaster)*
#   * *Estimated cost of model calls based on tokens (excluding Perplexity info used): $0.076*
#   * *Estimated (rough) cost of Perplexity call (if using recent Perplexity search, and including LLM prompt completion): $0.008*
#   * ***Final weighted forecast: 63%***
#
#   ---
#
#
# Successfully predicted 63.0 on question 26004
# Comment Success!
# Output Reasoning:
# ### One-Sentence Summary of Reasoning from Each Forecaster
#
# **Forecaster A**: Evaluated the current trends, historical performance, and likely regression of Trump's post-debate lead to predict a 45% probability of Trump's lead over Biden being between 2 and 3 points on July 15, 2024.
#
# **Forecaster B**: Considered current polling data, post-debate impacts, and historical trends to conclude a 60% probability that Trump’s lead over Biden will be in the 2 to 3 points range on July 15, 2024.
#
# **Forecaster C**: Analyzed present trends and political dynamics, applied Occam's razor and common forecasting biases, and extremized the forecast to determine an 80% probability that Trump's lead will fall between 2 and 3 points on July 15, 2024.
#
# ### My Forecast
#
# **Step-by-Step Reasoning and Forecast**
#
# 1. **Current Polling Data**:
#    - As of July 5, 2024, Trump is leading Biden by +2.4 percentage points.
#
# 2. **Recent Shifts and Trends**:
#    - Post-debate, there has been a significant shift in favor of Trump, widening his lead.
#    - Historical data suggest debate impacts can cause immediate shifts that might taper off.
#
# 3. **Historical Performance and Base Rates**:
#    - Review of historical performance indicates that debate impacts are usually temporary and tend to stabilize within a couple of weeks.
#    - Poll numbers typically move within narrow bands unless influenced by major events or crises.
#
# 4. **Political Climate and Upcoming Events**:
#    - Biden's campaign efforts to mitigate the negative impacts of the debate and upcoming Democratic National Convention could influence polling trends.
#    - Internal party pressure and public sentiment may continue to exert influence on the candidate’s standings.
#
# 5. **Impact of Media and Public Opinion**:
#    - The media narrative and public opinion hold considerable sway during post-debate periods, often resulting in multipoint swings.
#    - Trump's lead could either consolidate further if negative perceptions of Biden persist or decrease if Biden's counter-campaign is effective.
#
# 6. **Poll Stability and Fluctuations**:
#    - Polling averages help smooth out daily fluctuations, making extreme swings less likely absent significant new developments.
#
# **Consolidating Influences and Reasoning**:
#    - Forecaster A’s assessment that immediate post-debate shocks tend to soften and revert aligns with historical trends.
#    - Forecaster B’s analysis also correctly identifies the importance of current trends and volatility post-debate.
#    - Forecaster C’s use of Occam’s razor indicates a strong likelihood of stability in the 2 to 3 points range, based on current data.
#
# By integrating these insights, I recognize that while there is a clear trend following the debate favoring Trump, historical data and inherent polling stability suggest that the increase might moderate. This makes a lead of 2 to 3 points a likely scenario.
#
# ### Final Calculation
#
# Given the above evaluations and the likelihood of a stable lead within this range factoring in historical corrections post initial shock periods, I estimate:
#
# **Probability: 65%**
#
# FINAL WEIGHTED FORECAST:
# 63%
#
# Overall cost was: $0.07588
#
# ################ NEXT QUESTION #################
